# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-ea5eafa3-e765-48a5-a720-c7ff264f1896" name="files[]" multiple disabled />
#      <output id="result-ea5eafa3-e765-48a5-a720-c7ff264f1896">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving income.xls to income.xls
# ...

# %%
df =pd.read_excel('income.xls',header=3) 
df
# Out:
#        ภาค และจังหวัด  ... Region and province
# 0                 NaN  ...                 NaN
# 1                 NaN  ...                 NaN
# 2     ทั่วราชอาณาจักร  ...       Whole Kingdom
# 3            ตอนพิเศษ  ...     Greater Bangkok
# 4       กรุงเทพมหานคร  ...             Bangkok
# ..                ...  ...                 ...
# 84           นราธิวาส  ...          Narathiwat
# 85                NaN  ...                 NaN
# 86                NaN  ...                 NaN
# 87             ที่มา:  ...                 NaN
# 88            Source:  ...                 NaN
#
# [89 rows x 13 columns]

# %%
greaterbargkok = df.iloc[4:8,:]  #ใส่เลขเกิน 1 เลข
greaterbargkok
# Out:
#       ภาค และจังหวัด Unnamed: 1     2541  ...     2556     2558  Region and province
# 4      กรุงเทพมหานคร        NaN  26054.0  ...  49190.8  45571.7              Bangkok
# 5        สมุทรปราการ        NaN  18100.0  ...  29575.3  25457.2         Samut Prakan
# 6            นนทบุรี        NaN  24211.0  ...  30663.6  36884.0           Nonthaburi
# 7           ปทุมธานี        NaN  21793.0  ...  33461.3  41056.9         Pathum Thani
#
# [4 rows x 13 columns]

# %%
#matplotlib.pyplot.bar(x, height, width=0.8, bottom=None, , align='center', data=None, *kwargs)[source]

# %%
#Barchart(กราฟแท่ง)

#สร้างกราฟแท่งเปรียบเทียบรายได้ในปี 2541 ของจังหวัดกรุงเทพและปริมณฑล

# %%
plt.bar([1,2,3,4],greaterbargkok.iloc[:,2])#เลือกทุกแถว เลือกคอลัมน์ที่2
plt.title(u'กราฟแท่งเปรียบเทียบรายได้ในปี 2541 ของจังหวัดกรุงเทพและปริมณฑล',fontname='Tahoma',fontsize='18')  #ตั้งชื่อกราฟ
plt.xlabel('Provinces')
plt.ylabel('Income Eath/Month/Household')
# Out:
# Text(0, 0.5, 'Income Eath/Month/Household')
# findfont: Font family ['Tahoma'] not found. Falling back to DejaVu Sans.
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 3585 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 3619 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 3634 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 3615 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 3649 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.bar([1,2,3,4],greaterbargkok.iloc[:,2],tick_label=greaterbargkok.iloc[:,-1])#เลือกทุกแถว เลือกคอลัมน์ที่2
plt.title('Barchart comparing average monthly income of provinces in Greater Bangkok in 2541')  #ตั้งชื่อกราฟ
plt.xlabel('Provinces')
plt.ylabel('Income Eath/Month/Household')
# Out:
# Text(0, 0.5, 'Income Eath/Month/Household')

# %%
#compare different years

# %%
plt.bar([1-(0.35/2),2-(0.35/2),3-(0.35/2),4-(0.35/2)],greaterbargkok.iloc[:,-2],width=0.35,tick_label=greaterbargkok.iloc[:,-1],color = 'r',label ='2558',align='edge')
plt.bar([1+(0.35/2),2+(0.35/2),3+(0.35/2),4+(0.35/2)],greaterbargkok.iloc[:,2],width=0.35,tick_label=greaterbargkok.iloc[:,-1],color = 'b',label ='2541',align='edge')
plt.title('Barchart comparing average monthly income of provinces in Greater Bangkok in 2541,2558')  #ตั้งชื่อกราฟ
plt.xlabel('Provinces')
plt.legend(loc=1)#บอกปีและตำแหน่งการแสดง
plt.ylabel('Income Eath/Month/Household')
# Out:
# Text(0, 0.5, 'Income Eath/Month/Household')

# %%
saledata = pd.DataFrame([{'North':20,'East':10,'West':90,'South':120},
                                            {'North':120,'East':20,'West':50,'South':90}])
saledata
# Out:
#    North  East  West  South
# 0     20    10    90    120
# 1    120    20    50     90

# %%
plt.bar([1,2],saledata.iloc[:,0],tick_label=['Company A','Company B'])
plt.bar([1,2],saledata.iloc[:,1],bottom=saledata.iloc[:,0],tick_label=['Company A','Company B'])
plt.bar([1,2],saledata.iloc[:,2],bottom=saledata.iloc[:,0],tick_label=['Company A','Company B'])
# Out:
# <BarContainer object of 2 artists>

# %%
plt.bar([1,2],saledata.iloc[:,0],tick_label=['Company A','Company B'],color = 'r')
plt.bar([1,2],saledata.iloc[:,1],bottom=saledata.iloc[:,0],tick_label=['Company A','Company B'])#bottom คือฐาน
plt.bar([1,2],saledata.iloc[:,2],bottom=saledata.iloc[:,0]+saledata.iloc[:,1],tick_label=['Company A','Company B'])
plt.bar([1,2],saledata.iloc[:,3],bottom=saledata.iloc[:,0]+saledata.iloc[:,1]+saledata.iloc[:,2],tick_label=['Company A','Company B'])
# Out:
# <BarContainer object of 2 artists>

# %%
#Histrogram

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Fixing random stote for reproducibility  สุ่ม
np.random.seed(19680801)

# %%
np.random.randn()
# Out:
# 1.0493043103878812

# %%
mu, sigma = 100,15
x = mu + sigma * np.random.randn(10000)

# %%
x
# Out:
# array([112.99148762, 108.267019  , 125.92116686, ...,  73.28843349,
#         77.0735325 , 107.25414148])

# %%
plt.hist(x,50,density=True,facecolor='g' ,alpha = 0.75);

# %%
#Treemap

# %%
# !pip install squarify

# %%
import squarify

# %%
volume = [350, 220, 170, 150, 50]

# %%
squarify.plot(sizes=volume)

# %%
labels = ['Liquid\n volume: 350k', 'Savoury\n volume: 220k',
          'Sugar\n volume: 170k', 'Frozen\n volume: 150k',
          'Non-food\n volume: 50k']#
color_list = ['#0f7216', '#b2790c', '#ffe9a3',
                   '#f9d4d4', '#d35158', '#ea3033'] #อ้างถึงสี

# %%
squarify.plot(sizes=volume, label=labels,
              color=color_list, alpha=0.7)

# %%
#Radar char

# %%
import pandas as pd
from math import pi

# %%
pi
# Out:
# 3.141592653589793

# %%
sales = {'client_id':['c1','c2','c3','c4'],
         'cheese': [2, 5, 4,3],
         'beer': [2, 1, 3,5],
         'chicken': [5,3,3,4],
         'bread':[4,3,2,1],
        'coffee':[2,3,5,3]}
df = pd.DataFrame.from_dict(sales)

# %%
df
# Out:
#   client_id  cheese  beer  chicken  bread  coffee
# 0        c1       2     2        5      4       2
# 1        c2       5     1        3      3       3
# 2        c3       4     3        3      2       5
# 3        c4       3     5        4      1       3

# %%
categories = list(df)[1:]

# %%
categories
# Out:
# ['cheese', 'beer', 'chicken', 'bread', 'coffee']

# %%
values = df.mean().values.flatten().tolist()
values += values[:1]

# %%
values = df.mean().values.flatten().tolist()
values
# Out:
# [3.5, 2.75, 3.75, 2.5, 3.25]

# %%
angles = [n / float(len(categories)) * 2 * pi for n in range(len(categories))]
angles += angles[:1]

# %%
values
# Out:
# [3.5, 2.75, 3.75, 2.5, 3.25]

# %%
angles
# Out:
# [0.0,
#  1.2566370614359172,
#  2.5132741228718345,
#  3.7699111843077517,
#  5.026548245743669,
#  0.0]

# %%
categories = list(df)[1:]
values = df.mean().values.flatten().tolist()
values += values[:1] # repeat the first value to close the circular graph
angles = [n / float(len(categories)) * 2 * pi for n in range(len(categories))]
angles += angles[:1]

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 8),
                       subplot_kw=dict(polar=True))
plt.xticks(angles[:-1], categories, color='grey', size=12)
plt.yticks(np.arange(1, 6), ['1', '2', '3', '4', '5'],
           color='grey', size=12)

plt.ylim(0, 5)
ax.set_rlabel_position(30)  #เตรียมพื้นที่สำหรับการพอต

# %%
#การเตรียมพื้นที่สำหรับการพอต
angles = [n / float(len(categories)) * 2 * pi for n in range(len(categories))]
angles += angles[:1]

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 8),
                       subplot_kw=dict(polar=True))
plt.xticks(angles[:-1], categories, color='grey', size=12)
plt.yticks(np.arange(1, 6), ['1', '2', '3', '4', '5'],
           color='grey', size=12)

plt.ylim(0, 5)
ax.set_rlabel_position(30)  #เตรียมพื้นที่สำหรับการพอต

# part 1
val_c1 = df.loc[0].drop('client_id').values.flatten().tolist()
val_c1 += val_c1[:1]
ax.plot(angles, val_c1, linewidth=1,
        linestyle='solid', label='Client c1')
ax.fill(angles, val_c1, 'skyblue', alpha=0.4)
 
# part 2
val_c2=df.loc[1].drop('client_id').values.flatten().tolist()
val_c2 += val_c2[:1]
ax.plot(angles, val_c2, linewidth=1,
        linestyle='solid', label='Client c2')
ax.fill(angles, val_c2, 'lightpink', alpha=0.4)
 
plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))
plt.show()

# %%
#Word cloud ก้อนเมฆคำ

# %%
import pandas as pd

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-34b84969-5c53-4c75-b59d-20e59c402f2b" name="files[]" multiple disabled />
#      <output id="result-34b84969-5c53-4c75-b59d-20e59c402f2b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving message.csv to message.csv
# ...

# %%
words =pd.read_csv('message.csv')

# %%
words
# Out:
#      Unnamed: 0  ...                                            etag
# 0             0  ...   W/"datetime'2020-02-20T03%3A10%3A29.464192Z'"
# 1             1  ...  W/"datetime'2020-02-20T03%3A10%3A52.8537261Z'"
# 2             2  ...  W/"datetime'2020-02-20T03%3A11%3A27.7265177Z'"
# 3             3  ...  W/"datetime'2020-02-20T03%3A11%3A50.5179595Z'"
# 4             4  ...  W/"datetime'2020-02-20T03%3A11%3A53.7160165Z'"
# ..          ...  ...                                             ...
# 963         963  ...  W/"datetime'2020-02-25T11%3A48%3A34.5532534Z'"
# 964         964  ...  W/"datetime'2020-02-25T04%3A17%3A00.0360436Z'"
# 965         965  ...  W/"datetime'2020-02-25T04%3A17%3A06.6102857Z'"
# 966         966  ...   W/"datetime'2020-02-25T04%3A17%3A19.324156Z'"
# 967         967  ...  W/"datetime'2020-02-25T04%3A17%3A25.0544679Z'"
#
# [968 rows x 6 columns]

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# %%
text = ('Data science is an interdisciplinary field that uses scientificmethods, processes, algorithms and systems toextract knowledge and insightsfrom data in various forms,bothstructured and unstructured, similar to data mining. Datascience is a concept to unify statistics, dataanalysis, machinelearning and their related methods in order to understand andanalyze actualphenomena with data. It employs techniques and theories drawnfrom many fieldswithin the context of mathematics, statistics, informationscience, andcomputer science. Turing award winner Jim Gray imagineddatascience as afourth paradigm of science (empirical,theoretical,computational and nowdata-driven) and asserted that everything about science ischanging because ofthe impact of information technology and the data deluge. In2012, when HarvardBusiness Review called it The Sexiest Job of the 21st Century,the term datascience became a buzzword. It is now often usedinterchangeably with earlierconcepts like business analytics,business intelligence, predictive modeling,and statistics. Even the suggestion that data science is sexywas paraphrasingHans Rosling, featured in a 2011 BBC documentary with thequote, Statistics isnow the sexiest subject around. Nate Silver referred to datascience as a sexedup term for statistics. In many cases, earlier approaches andsolutions are nowsimply rebranded as data science to be more attractive, whichcan cause theterm to become dilute beyond usefulness. While many universityprograms nowoffer a data science degree, there exists no consensus on adefinition orsuitable curriculum contents. To its discredit, however, manydata-science andbig-data projects fail to deliver useful results, often as aresult of poormanagement and utilization of resources')

# %%
text = ('Data science is an interdisciplinary field that uses scientific \
methods, processes, algorithms and systems to extract knowledge and insights\
from data in various forms, both structured and unstructured, similar to data\
mining. Data science is a concept to unify statistics, data analysis, machine\
learning and their related methods in order to understand and analyze actual\
phenomena with data. It employs techniques and theories drawn from many fields\
within the context of mathematics, statistics, information science, and\
computer science. Turing award winner Jim Gray imagined data science as a\
fourth paradigm of science (empirical, theoretical, computational and now\
data-driven) and asserted that everything about science is changing because of\
the impact of information technology and the data deluge. In 2012, when Harvard\
Business Review called it The Sexiest Job of the 21st Century, the term data\
science became a buzzword. It is now often used interchangeably with earlier\
concepts like business analytics, business intelligence, predictive modeling,\
and statistics. Even the suggestion that data science is sexy was paraphrasing\
Hans Rosling, featured in a 2011 BBC documentary with the quote, Statistics is\
now the sexiest subject around. Nate Silver referred to data science as a sexed\
up term for statistics. In many cases, earlier approaches and solutions are now\
simply rebranded as data science to be more attractive, which can cause the\
term to become dilute beyond usefulness. While many university programs now\
offer a data science degree, there exists no consensus on a definition or\
suitable curriculum contents. To its discredit, however, many data-science and\
big-data projects fail to deliver useful results, often as a result of poor\
management and utilization of resources')

# %%
wordcloud = WordCloud(width=1280, height=900, margin=0,colormap='Blues').generate(text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.margins(x=0, y=0)
plt.show()

# %%
#Home Work

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import pandas as pd

# %%
cc = pd.read_csv('message.csv')

# %%
ccnew= cd.iloc[:,4]
ccnew1= str(ccnew)

# %%
ccnew
# Out:
# 0                           Hello
# 1      img : not a parasite image
# 2                 img : Trichuris
# 3                   img : Ascaris
# 4                           อาการ
#                   ...
# 963                           บาย
# 964                       Dee kub
# 965                         ดีคับ
# 966                    สวัสดีครับ
# 967                            Hi
# Name: message, Length: 968, dtype: object

# %%
pp=''
for i in range(len(cc)):
        x = cc.iloc[i,4]
        pp += x

# %%
pp
# Out:
# 'Helloimg : not a parasite imageimg : Trichurisimg : Ascarisอาการชนิดของไข่พยาธิรู้ได้อย่างไรว่าติดพยาธิหวัดดีจ้าimg : Trichurisหวัดดีจ้าimg : hookwormsไข่พยาธิชื่อว่าอะไรไข่พยาธิชื่อว่าอะไรไข่พยาธิกลุ่มใดอาการรู้ได้อย่างไรว่าติดพยาธิimg : Trichurisimg : Trichurisimg : hookwormsลักษณะเด่นของไข่พยาธิimg : Trichurisหวัดดีจ้าาimg : not a parasite imageสวัสดีค่ะHelloจากรูปภาพเป็นไข่พยาธิชนิดใดimg : Taeniaimg : Trichurisอาการimg : OVลักษณะเด่นของไข่พยาธิไข่พยาธิชื่อว่าอะไรวิธีป้องกันHelloimg : not a parasite imageimg : Trichurisอาการimg : EnterobiusHelloimg : Taeniaimg : Ascarisimg : not a parasite imageimg : Taeniaรู้ได้อย่างไรว่าติดพยาธิลักษณะเด่นของไข่พยาธิลักษณะทั่วไปตัวเต็มวัยติดต่อสู่คนได้อย่างไรตัวเต็มวัยขนาดเท่าไหร่ไข่พยาธิกลุ่มใดimg : OVรู้ได้อย่างไรว่าติดพยาธิลักษณะเด่นของไข่พยาธิimg : Trichurisดีสวัสดีimg : not a parasite imageimg : Taeniaimg : Ascarisรู้ได้อย่างไรว่าติดพยาธิอาการชนิดของไข่พยาธิimg : Trichurisimg : Ascarisimg : Trichurisชนิดของไข่พยาธิลักษณะเด่นของไข่พยาธิไข่พย
# ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-684268f0-a04f-47aa-a05e-f84e98d3c2e3" name="files[]" multiple disabled />
#      <output id="result-684268f0-a04f-47aa-a05e-f84e98d3c2e3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving THSarabun.ttf to THSarabun (3).ttf
# ...

# %%
path = 'THSarabun.ttf'

# %%
regexp = r"[ก-๙a-zA-Z']+"

# %%
# !pip install WordCloud

# %%
wordcloud = WordCloud(font_path=path, relative_scaling = 0.3,min_font_size=1,background_color="white",
                      width=1024,height=768,max_words=2000,  
                      scale=3,font_step=4,collocations=False,regexp=regexp,margin=2,colormap='plasma').generate(pp)

# %%
fig, ax = plt.subplots(1, 1, figsize=(16, 12))
ax.imshow(wordcloud, interpolation='bilinear')
ax.axis("off")
fig.show()
